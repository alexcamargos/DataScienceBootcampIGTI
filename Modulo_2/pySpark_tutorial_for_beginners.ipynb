# %% [markdown]
# # Primeiros Passos com Spark e Python (PySpark) - Parte 01
#
# O [Apache Spark](https://spark.apache.org/) é uma ferramenta Big Data que tem o objetivo de processar grandes conjuntos de dados de forma paralela e distribuída. Ela estende o modelo de programação MapReduce popularizado pelo Apache Hadoop, facilitando bastante o desenvolvimento de aplicações de processamento de grandes volumes de dados. Além do modelo de programação estendido, o Spark também apresenta uma performance muito superior ao Hadoop, chegando em alguns casos a apresentar uma performance quase 100x maior. Existem API's para as principais linguagem disponíveis no mercado, com destaque para PYTHON, JAVA, R, JULIA, SCALA.
#
# Outra grande vantagem do Spark, é que todos os componentes funcionam integrados na própria ferramenta, como o Spark Streaming, o Spark SQL e o GraphX, diferentemente do Hadoop, onde é necessário utilizar ferramentas que se integram a ele, mas que são distribuídas separadamente, como o Apache Hive.
#
# O Spark tem diversos componentes para diferentes tipos de processamentos, todos construídos sobre o Spark Core, que é o componente que disponibiliza as funções básicas para o processamento como as funções map, reduce, filter e collect:
#
# - O Spark Streaming, que possibilita o processamento de fluxos em tempo real;
# - O GraphX, que realiza o processamento sobre grafos;
# - O SparkSQL para a utilização de SQL na realização de consultas e processamento sobre os dados no Spark;
# - A MLlib, que é a biblioteca de aprendizado de máquina, com deferentes algoritmos para as mais diversas atividades, como clustering.

# %%
from pyspark.sql import SparkSession
from pyspark import SparkFiles
from pyspark.sql import functions as sql_f

# %%
# Criando o objeto SparkSession.
spark = SparkSession.builder.appName('PySpark_For_Beginners').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=382842048963492#setting/sparkui/0612-183516-on9u3l5/driver-7173463258986475302">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Link para acesso ao dataset.
DATASET_URL = 'https://raw.githubusercontent.com/alexcamargos/DataScienceBootcampIGTI/main/Modulo_2/total_frota_2022.csv'

# %% [markdown]
# ## Introdução aos DataFrames
# Um DataFrame é uma estrutura de dados rotulada bidimensional com colunas de tipos potencialmente diferentes. Considere um DataFrame como uma planilha, uma tabela SQL ou um dicionário de objetos de série. Para obter mais informações e exemplos, confira o [Guia de Início Rápido](https://spark.apache.org/docs/latest/api/python/getting_started/quickstart_df.html) no site da documentação do Apache Spark.

# %%
# Informando ao Spark onde esta o arquivo para download.
spark.sparkContext.addFile(DATASET_URL)

# Carregando o dataset. Nosso arquivo CSV tem cabeçalho definido e usa encoding Windows-1252.
# encoding=Windows-1252 - Define o encoding dos dados.
# inferSchema=True - Tenta determinar o schema a partir dos dados.
df = spark.read.option('header', True) \
               .option('encoding', 'Windows-1252') \
               .option('inferSchema', 'True') \
               .csv(f"file://{SparkFiles.get('total_frota_2022.csv')}")

# %%
df.show()
# Out:
# +---+-------+--------------------+-------------+--------+-----------+-----------------+-------------------+----------+--------+--------------------+--------------+--------+-----------+---------+--------------------+-----+-----+-----+--------------+--------+-----------+----------+--------------+---------------+-------------+--------------+----------+
# |_c0|  Placa|              Modelo|        Marca|AnoFabr.|Combustível|           Chassi|                Cor|  Potência|Cilindro|           Aquisição|   Conservação|Situação|Combustivel|  Renavam|                Tipo|Motor|Caixa|Local|Loc.Manutenção|Km Atual|Data Compra|Data Venda|Nota de compra|Valor de compra|Nota de venda|Valor de venda|Nº Apólice|
# +---+-------+--------------------+-------------+--------+-----------+-----------------+-------------------+----------+--------+--------------------+--------------+--------+-----------+---------+--------------------+-----+-----+-----
+-----------+-----------------+-------------------+----------+--------+--------------------+--------------+--------+-----------+---------+--------------------+-----+-----+-----+--------------+--------+-----------+----------+--------------+---------------+-------------+--------------+----------+
# only showing top 20 rows

# %%
# Exibindo os resultados em modo vertical.
# truncate - indica o tamanho das strings que podem ser exibidas.
df.show(n=5, truncate=42, vertical=True)
# Out:
# -RECORD 0------------------------------
#  Placa       | GMF1396
#  Modelo      | CAMINHAO TANQUE
#  Marca       | VOLKSWAGEN
#  AnoFabricao | 1995
#  Combustível | Diesel
#  Chassi      | 9BWXTACM3SDB90133
#  Cor         | BRANCA
#  Potência    | 134
#  Cilindro    | 6
#  Aquisição   | COMPRA
#  Conservação | Regular
#  Situação    | Ativa
#  Combustivel | Diesel
#  Renavam     | 650997018
#  Tipo        | CAR/CAMINHAO TANQUE
#  Motor       | null
#  Caixa       | null
#  Local       | null
#  KmAtual     | 35329
#  DataCompra  | 1995-01-12
#  DataVenda   | null
#  NotaCompra  | 0
#  ValorCompra | null
#  NumApolice  | null
# -RECORD 1------------------------------
#  Placa       | GMF1564
#  Modelo      | PARATI CLI
#  Marca       | VOLKSWAGEN
#  AnoFabricao | 1996
#  Combustível | Gasolina
#  Chassi      | 9BWZZZ379TT163437
#  Cor         | BRANCA
#  Potência    | 081 CV-1.6
#  Cilindro    | 4
#  Aquisição   | DOACAO TERMO 02/2012
#  Conservação | Anti-econômico
#  Situação    | Ativa
#  Combustivel | Gasolina
#  Renavam     | 660911655
#  Tipo        | PAS/AUTOMOVEL
#  Motor       | null
#  Caixa       | null
#  Local       | null
#  KmAtual     | 233615
#  DataCompra  | 2012-01-11
#  DataVenda   | null
#  NotaCompra  | 0
#  ValorCompra | 18290.0
#  NumApolice  | null
# -RECORD 2------------------------------
#  Placa       | GMF1641
#  Modelo      | GOL 1.6 MI
#  Marca       | VOLKSWAGEN
#  AnoFabricao | 1997
#  Combustível | Gasolina
#  Chassi      | 9BWZZZ377VP501275
#  Cor         | BRANCA
#  Potência    | 1.6 081 CV
#  Cilindro    | 4
#  Aquisição   | DOACAO TERMO 2013000045
#  Conservação | Anti-econômico
#  Situação    | Ativa
#  Combustivel | Gasolina
#  Renavam     | 669493210
#  Tipo        | PAS/AUTOMOVEL
#  Motor       | null
#  Caixa       | null
#  Local       | null
#  KmAtual     | 57315
#  DataCompra  | 2013-01-17
#  DataVenda   | null
#  NotaCompra  | 0
#  ValorCompra | null
#  NumApolice  | null
# -RECORD 3------------------------------
#  Placa       | GMF1750
#  Modelo      | VAN SPRINTER
#  Marca       | MERCEDES BENZ
#  AnoFabricao | 1997
#  Combustível | Diesel
#  Chassi      | 8AC690341VA501494
#  Cor         | BRANCA
#  Potência    | 95 CV
#  Cilindro    | 4
#  Aquisição   | COMPRA
#  Conservação | Anti-econômico
#  Situação    | Ativa
#  Combustivel | Diesel
#  Renavam     | 677009291
#  Tipo        | PAS/MICROONIBUS
#  Motor       | null
#  Caixa       | null
#  Local       | null
#  KmAtual     | 359394
#  DataCompra  | 1997-01-04
#  DataVenda   | null
#  NotaCompra  | 0
#  ValorCompra | null
#  NumApolice  | null
# -RECORD 4------------------------------
#  Placa       | GMF1756
#  Modelo      | VAN SPRINTER
#  Marca       | MERCEDES BENZ
#  AnoFabricao | 1997
#  Combustível | Diesel
#  Chassi      | 8AC690341VA503492
#  Cor         | BRANCA
#  Potência    | 95 CV
#  Cilindro    | 4
#  Aquisição   | COMPRA
#  Conservação | Regular
#  Situação    | Ativa
#  Combustivel | Diesel
#  Renavam     | 677210230
#  Tipo        | PAS/MICROONIBUS
#  Motor       | null
#  Caixa       | null
#  Local       | null
#  KmAtual     | 365290
#  DataCompra  | 1997-01-30
#  DataVenda   | null
#  NotaCompra  | 0
#  ValorCompra | null
#  NumApolice  | null
# only showing top 5 rows

# %%
# Visualizando as colunas do dataframe.
df.columns
# Out:
# Out[7]: ['_c0',
#  'Placa',
#  'Modelo',
#  'Marca',
#  'AnoFabr.',
#  'Combustível',
#  'Chassi',
#  'Cor',
#  'Potência',
#  'Cilindro',
#  'Aquisição',
#  'Conservação',
#  'Situação',
#  'Combustivel',
#  'Renavam',
#  'Tipo',
#  'Motor',
#  'Caixa',
#  'Local',
#  'Loc.Manutenção',
#  'Km Atual',
#  'Data Compra',
#  'Data Venda',
#  'Nota de compra',
#  'Valor de compra',
#  'Nota de venda',
#  'Valor de venda',
#  'Nº Apólice']

# %%
# Visualizando o schema dos dados em formato árvore.
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- Placa: string (nullable = true)
#  |-- Modelo: string (nullable = true)
#  |-- Marca: string (nullable = true)
#  |-- AnoFabr.: integer (nullable = true)
#  |-- Combustível: string (nullable = true)
#  |-- Chassi: string (nullable = true)
#  |-- Cor: string (nullable = true)
#  |-- Potência: string (nullable = true)
#  |-- Cilindro: integer (nullable = true)
#  |-- Aquisição: string (nullable = true)
#  |-- Conservação: string (nullable = true)
#  |-- Situação: string (nullable = true)
#  |-- Combustivel: string (nullable = true)
#  |-- Renavam: integer (nullable = true)
#  |-- Tipo: string (nullable = true)
#  |-- Motor: string (nullable = true)
#  |-- Caixa: string (nullable = true)
#  |-- Local: string (nullable = true)
#  |-- Loc.Manutenção: string (nullable = true)
#  |-- Km Atual: integer (nullable = true)
#  |-- Data Compra: string (nullable = true)
#  |-- Data Venda: string (nullable = true)
#  |-- Nota de compra: integer (nullable = true)
#  |-- Valor de compra: string (nullable = true)
#  |-- Nota de venda: integer (nullable = true)
#  |-- Valor de venda: integer (nullable = true)
#  |-- Nº Apólice: string (nullable = true)

# %%
# Visualizando o tamanho do datafame.
print(f'Nosso dataframe tem {df.count()} linhas e {len(df.columns)} colunas.')
# Out:
# Nosso dataframe tem 273 linhas e 28 colunas.

# %%
# Visualizando os cinco primeiros items da dataframe.
df.head(3)
# Out:
# Out[10]: [Row(_c0=1, Placa='GMF1396', Modelo='CAMINHAO TANQUE', Marca='VOLKSWAGEN', AnoFabr.=1995, Combustível='Diesel', Chassi='9BWXTACM3SDB90133', Cor='BRANCA', Potência='134', Cilindro=6, Aquisição='COMPRA', Conservação='Regular', Situação='Ativa', Combustivel='Diesel', Renavam=650997018, Tipo='CAR/CAMINHAO TANQUE', Motor=None, Caixa=None, Local=None, Loc.Manutenção=None, Km Atual=35329, Data Compra='12/11/1995', Data Venda=None, Nota de compra=0, Valor de compra='79785,2', Nota de venda=0, Valor de venda=0, Nº Apólice=None),
#  Row(_c0=2, Placa='GMF1564', Modelo='PARATI CLI', Marca='VOLKSWAGEN', AnoFabr.=1996, Combustível='Gasolina', Chassi='9BWZZZ379TT163437', Cor='BRANCA', Potência='081 CV-1.6', Cilindro=4, Aquisição='DOACAO TERMO 02/2012', Conservação='Anti-econômico', Situação='Ativa', Combustivel='Gasolina', Renavam=660911655, Tipo='PAS/AUTOMOVEL', Motor=None, Caixa=None, Local=None, Loc.Manutenção=None, Km Atual=233615, Data Compra='11/09/2012', Data Venda=None, Nota de compra=0, Valor de compra='18290', Nota de venda=0, Valor de venda=0, Nº Apólice=None),
#  Row(_c0=3, Placa='GMF1641', Modelo='GOL 1.6 MI', Marca='VOLKSWAGEN', AnoFabr.=1997, Combustível='Gasolina', Chassi='9BWZZZ377VP501275', Cor='BRANCA', Potência='1.6 081 CV', Cilindro=4, Aquisição='DOACAO TERMO 2013000045', Conservação='Anti-econômico', Situação='Ativa', Combustivel='Gasolina', Renavam=669493210, Tipo='PAS/AUTOMOVEL', Motor=None, Caixa=None, Local=None, Loc.Manutenção=None, Km Atual=57315, Data Compra='17/10/2013', Data Venda=None, Nota de compra=0, Valor de compra='13729,5', Nota de venda=0, Valor de venda=0, Nº Apólice=None)]

# %%
# Visualizando os cinco últimos itens do dataframe.
df.tail(3)
# Out:
# Out[11]: [Row(_c0=None, Placa='TOTAL 267', Modelo=None, Marca=None, AnoFabr.=None, Combustível=None, Chassi=None, Cor=None, Potência=None, Cilindro=None, Aquisição=None, Conservação=None, Situação=None, Combustivel=None, Renavam=None, Tipo=None, Motor=None, Caixa=None, Local=None, Loc.Manutenção=None, Km Atual=None, Data Compra=None, Data Venda=None, Nota de compra=None, Valor de compra=None, Nota de venda=None, Valor de venda=None, Nº Apólice=None),
#  Row(_c0=None, Placa='RELATÓRIO DE VEÍCULOS DA FROTA', Modelo=None, Marca=None, AnoFabr.=None, Combustível=None, Chassi=None, Cor=None, Potência=None, Cilindro=None, Aquisição=None, Conservação=None, Situação=None, Combustivel=None, Renavam=None, Tipo=None, Motor=None, Caixa=None, Local=None, Loc.Manutenção=None, Km Atual=None, Data Compra=None, Data Venda=None, Nota de compra=None, Valor de compra=None, Nota de venda=None, Valor de venda=None, Nº Apólice=None),
#  Row(_c0=None, Placa='Da depart. :   até :', Modelo=None, Marca=None, AnoFabr.=None, Combustível=None, Chassi=None, Cor=None, Potência=None, Cilindro=None, Aquisição=None, Conservação=None, Situação=None, Combustivel=None, Renavam=None, Tipo=None, Motor=None, Caixa=None, Local=None, Loc.Manutenção=None, Km Atual=None, Data Compra=None, Data Venda=None, Nota de compra=None, Valor de compra=None, Nota de venda=None, Valor de venda=None, Nº Apólice=None)]

# %%
# Eliminando colunas do dataframe.
df = df.drop('_c0', 'Nota de venda', 'Valor de venda', 'Loc.Manutenção')
df.columns
# Out:
# Out[12]: ['Placa',
#  'Modelo',
#  'Marca',
#  'AnoFabr.',
#  'Combustível',
#  'Chassi',
#  'Cor',
#  'Potência',
#  'Cilindro',
#  'Aquisição',
#  'Conservação',
#  'Situação',
#  'Combustivel',
#  'Renavam',
#  'Tipo',
#  'Motor',
#  'Caixa',
#  'Local',
#  'Km Atual',
#  'Data Compra',
#  'Data Venda',
#  'Nota de compra',
#  'Valor de compra',
#  'Nº Apólice']

# %%
sql_f.col('Data Compra')
# Out:
# Out[13]: Column<'Data Compra'>

# %%
# Renomeando a coluna AnoFabr. para AnoFabricao.
df = df.withColumnRenamed('AnoFabr.', 'AnoFabricao') \
       .withColumnRenamed('Nº Apólice', 'NumApolice') \
       .withColumnRenamed('Km Atual', 'KmAtual')

# %%
# Renomeando colunas em lote.
columns_names = ['Data Compra','Data Venda','Nota de compra', 'Valor de compra']
new_columns_names = [column.title().replace(' ', '').replace('De', '') for column in columns_names]
columns_names_mapping = dict(zip(columns_names, new_columns_names))

df = df.select([sql_f.col(column).alias(columns_names_mapping.get(column, column)) for column in df.columns])

# %%
sql_f.to_date(sql_f.col('DataCompra'), 'dd-mm-yyyy').alias('Data')
# Out:
# Out[16]: Column<'to_date(DataCompra, dd-mm-yyyy) AS Data'>

# %%
# Transformando as colunas Data Compra e Data Venda em objetos do tipo data.
df = df.withColumn('DataCompra', sql_f.to_date(sql_f.col('DataCompra'), 'dd/mm/yyyy').alias('DataCompra'))
df = df.withColumn('DataVenda', sql_f.to_date(sql_f.col('DataVenda'), 'dd/mm/yyyy').alias('DataVenda'))

# %%
# Transformando a coluna Valor de compra em float.
df = df.withColumn('ValorCompra', df['ValorCompra'].cast('double'))

# %%
df.printSchema()
# Out:
# root
#  |-- Placa: string (nullable = true)
#  |-- Modelo: string (nullable = true)
#  |-- Marca: string (nullable = true)
#  |-- AnoFabricao: integer (nullable = true)
#  |-- Combustível: string (nullable = true)
#  |-- Chassi: string (nullable = true)
#  |-- Cor: string (nullable = true)
#  |-- Potência: string (nullable = true)
#  |-- Cilindro: integer (nullable = true)
#  |-- Aquisição: string (nullable = true)
#  |-- Conservação: string (nullable = true)
#  |-- Situação: string (nullable = true)
#  |-- Combustivel: string (nullable = true)
#  |-- Renavam: integer (nullable = true)
#  |-- Tipo: string (nullable = true)
#  |-- Motor: string (nullable = true)
#  |-- Caixa: string (nullable = true)
#  |-- Local: string (nullable = true)
#  |-- KmAtual: integer (nullable = true)
#  |-- DataCompra: date (nullable = true)
#  |-- DataVenda: date (nullable = true)
#  |-- NotaCompra: integer (nullable = true)
#  |-- ValorCompra: double (nullable = true)
#  |-- NumApolice: string (nullable = true)

# %% [markdown]
# ## Operações de Seleção e Filtragem

# %%
# Selecionando apenas uma coluna do dataframe.
df.select('Placa').show()
# Out:
# +-------+
# |  Placa|
# +-------+
# |GMF1396|
# |GMF1564|
# |GMF1641|
# |GMF1750|
# |GMF1756|
# |GMF2408|
# |GMF2414|
# |GMF2445|
# |GMF2581|
# |GMF2673|
# |GMF2794|
# |GMF2862|
# |GMF3059|
# |GMF3118|
# |GMF3242|
# |GMF3245|
# |GMF3249|
# |GMF3252|
# |GMF3253|
# |GMF3254|
# +-------+
# only showing top 20 rows

# %%
# Selecionando várias colunas ao mesmo tempo.
df.select(['Placa', 'Modelo', 'Marca', 'ValorCompra']).show()
# Out:
# +-------+--------------------+-------------+------------+
# |  Placa|              Modelo|        Marca| ValorCompra|
# +-------+--------------------+-------------+------------+
# |GMF1396|     CAMINHAO TANQUE|   VOLKSWAGEN|        null|
# |GMF1564|          PARATI CLI|   VOLKSWAGEN|     18290.0|
# |GMF1641|          GOL 1.6 MI|   VOLKSWAGEN|        null|
# |GMF1750|        VAN SPRINTER|MERCEDES BENZ|        null|
# |GMF1756|        VAN SPRINTER|MERCEDES BENZ|        null|
# |GMF2408|      CAMINHAO 608 D|MERCEDES BENZ|        null|
# |GMF2414|     CAMINHAO  L1314|MERCEDES BENZ|        null|
# |GMF2445|         ONIBUS 1314|MERCEDES BENZ|        null|
# |GMF2581|       KOMBI PICK-UP|   VOLKSWAGEN|        null|
# |GMF2673|    MICRO-ONIBUS 708|MERCEDES BENZ|        null|
# |GMF2794|        CAMINHAO 608|MERCEDES BENZ| 3.7018287E7|
# |GMF2862|     CAMINHAO  L1113|MERCEDES BENZ|1.19980655E8|
# |GMF3059|      STRADA WORKING|         FIAT|        null|
# |GMF3118|M. POLO VIAGGIO G...|MERCEDES BENZ|     98850.0|
# |GMF3242|PICK-UP COURIER 1...|         FORD|        null|
# |GMF3245|   PICK-UP S10 2.2 S|    CHEVROLET|     24699.0|
# |GMF3249|    KOMBI - STANDARD|   VOLKSWAGEN|        null|
# |GMF3252|    KOMBI - STANDARD|   VOLKSWAGEN|        null|
# |GMF3253|        VAN SPRINTER|MERCEDES BENZ|     57970.0|
# |GMF3254|   PICK-UP S10 2.2 S|    CHEVROLET|     24699.0|
# +-------+--------------------+-------------+------------+
# only showing top 20 rows

# %%
# Filtrando apenas os veículos da marca VOLKSWAGEN.
df.filter(df['Marca'] == 'FORD').select(['Placa',
                                         'Modelo',
                                         'Marca',
                                         'DataCompra',
                                         'ValorCompra']).show()
# Out:
# +-------+--------------------+-----+----------+-----------+
# |  Placa|              Modelo|Marca|DataCompra|ValorCompra|
# +-------+--------------------+-----+----------+-----------+
# |GMF3242|PICK-UP COURIER 1...| FORD|2000-01-12|       null|
# |GMF5754|          FIESTA 1.6| FORD|2009-01-02|       null|
# |GMF5755|          FIESTA 1.6| FORD|2009-01-02|       null|
# |GMF5756|          FIESTA 1.6| FORD|2009-01-02|       null|
# |GMF5757|          FIESTA 1.6| FORD|2009-01-03|       null|
# |GMF5758|          FIESTA 1.6| FORD|2009-01-02|       null|
# |GMF5759|          FIESTA 1.6| FORD|2009-01-02|       null|
# |GMF6494|           RANGER XL| FORD|2010-01-12|    84900.0|
# |GMF6583|          FIESTA 1.6| FORD|2011-01-16|    35900.0|
# |GMF6584|          FIESTA 1.6| FORD|2011-01-16|    35900.0|
# |GXP5136|         PICK-UP F75| FORD|1983-01-29|  2298960.0|
# |HCG1E96|PICK-UP COURIER 1...| FORD|2012-01-15|        0.0|
# |HNX0284|  CAMINHAO BAU 815 N| FORD|2012-01-15|   145500.0|
# |NXY0160|VAN TRANSIT 350 L...| FORD|2017-01-21|    95000.0|
# |NYB3752|TANQUE CARGO 1722 CN| FORD|2012-01-17|   217900.0|
# +-------+--------------------+-----+----------+-----------+

# %%
# Filtrando os veículos da marca VOLKSWAGEN ou CHEVROLET.
df.filter((df['Marca'] == 'FORD') | 
          (df['Marca'] == 'CHEVROLET')).select(['Placa',
                                                'Modelo',
                                                'Marca',
                                                'DataCompra',
                                                'ValorCompra']).show()
# Out:
# +-------+--------------------+---------+----------+-----------+
# |  Placa|              Modelo|    Marca|DataCompra|ValorCompra|
# +-------+--------------------+---------+----------+-----------+
# |GMF3242|PICK-UP COURIER 1...|     FORD|2000-01-12|       null|
# |GMF3245|   PICK-UP S10 2.2 S|CHEVROLET|2000-01-15|    24699.0|
# |GMF3254|   PICK-UP S10 2.2 S|CHEVROLET|2000-01-15|    24699.0|
# |GMF3257|   PICK-UP S10 2.2 S|CHEVROLET|2000-01-15|    24699.0|
# |GMF3259|PICK-UP GM/S10 2.8 S|CHEVROLET|2000-01-15|    35795.0|
# |GMF3260|       GM/CORSA WIND|CHEVROLET|2000-01-15|    19563.0|
# |GMF3262|       GM/CORSA WIND|CHEVROLET|2000-01-15|    19563.0|
# |GMF3273|   PICK-UP S10 2.2 S|CHEVROLET|2000-01-15|    24699.0|
# |GMF3276|       GM/CORSA WIND|CHEVROLET|2000-01-15|    19563.0|
# |GMF3554|GM/S10 2.8 D CABI...|CHEVROLET|2012-01-24|    62063.0|
# |GMF4073|               ASTRA|CHEVROLET|2016-01-05|       null|
# |GMF4884|ASTRA SEDAN ELEGANCE|CHEVROLET|2006-01-28|    55500.0|
# |GMF4885|ASTRA SEDAN ELEGANCE|CHEVROLET|2006-01-28|    55500.0|
# |GMF5754|          FIESTA 1.6|     FORD|2009-01-02|       null|
# |GMF5755|          FIESTA 1.6|     FORD|2009-01-02|       null|
# |GMF5756|          FIESTA 1.6|     FORD|2009-01-02|       null|
# |GMF5757|          FIESTA 1.6|     FORD|2009-01-03|       null|
# |GMF5758|          FIESTA 1.6|     FORD|2009-01-02|       null|
# |GMF5759|          FIESTA 1.6|     FORD|2009-01-02|       null|
# |GMF6494|           RANGER XL|     FORD|2010-01-12|    84900.0|
# +-------+--------------------+---------+----------+-----------+
# only showing top 20 rows

# %%
# Filtrando os veículos com mais de 20 anos de fabricação.
df.filter(f'AnoFabricao < {2022 - 20}').select(['Placa',
                                                'Marca',
                                                'Modelo',
                                                'Conservação',
                                                'AnoFabricao',
                                                'DataCompra',
                                                'KmAtual',
                                                'ValorCompra']).show()
# Out:
# +-------+-------------+--------------------+--------------+-----------+----------+-------+------------+
# |  Placa|        Marca|              Modelo|   Conservação|AnoFabricao|DataCompra|KmAtual| ValorCompra|
# +-------+-------------+--------------------+--------------+-----------+----------+-------+------------+
# |GMF1396|   VOLKSWAGEN|     CAMINHAO TANQUE|       Regular|       1995|1995-01-12|  35329|        null|
# |GMF1564|   VOLKSWAGEN|          PARATI CLI|Anti-econômico|       1996|2012-01-11| 233615|     18290.0|
# |GMF1641|   VOLKSWAGEN|          GOL 1.6 MI|Anti-econômico|       1997|2013-01-17|  57315|        null|
# |GMF1750|MERCEDES BENZ|        VAN SPRINTER|Anti-econômico|       1997|1997-01-04| 359394|        null|
# |GMF1756|MERCEDES BENZ|        VAN SPRINTER|       Regular|       1997|1997-01-30| 365290|        null|
# |GMF2408|MERCEDES BENZ|      CAMINHAO 608 D|       Regular|       1986|1986-01-29| 183347|        null|
# |GMF2414|MERCEDES BENZ|     CAMINHAO  L1314|       Regular|       1988|1988-01-26| 108568|        null|
# |GMF2445|MERCEDES BENZ|         ONIBUS 1314|Anti-econômico|       1987|1987-01-20|  32885|        null|
# |GMF2581|   VOLKSWAGEN|       KOMBI PICK-UP|Anti-econômico|       1986|1986-01-29|  79715|        null|
# |GMF2673|MERCEDES BENZ|    MICRO-ONIBUS 708|Anti-econômico|       1987|1987-01-06|  50841|        null|
# |GMF2794|MERCEDES BENZ|        CAMINHAO 608|       Regular|       1985|1984-01-27| 255465| 3.7018287E7|
# |GMF2862|MERCEDES BENZ|     CAMINHAO  L1113|       Regular|       1985|1985-01-09| 142050|1.19980655E8|
# |GMF3059|         FIAT|      STRADA WORKING|       Regular|       1999|1999-01-09| 272552|        null|
# |GMF3118|MERCEDES BENZ|M. POLO VIAGGIO G...|           Bom|       2000|2000-01-30|  59938|     98850.0|
# |GMF3242|         FORD|PICK-UP COURIER 1...|           Bom|       2000|2000-01-12|  66961|        null|
# |GMF3245|    CHEVROLET|   PICK-UP S10 2.2 S|           Bom|       2000|2000-01-15| 187303|     24699.0|
# |GMF3249|   VOLKSWAGEN|    KOMBI - STANDARD|           Bom|       2000|2000-01-18|  81075|        null|
# |GMF3252|   VOLKSWAGEN|    KOMBI - STANDARD|           Bom|       2001|2000-01-14| 193323|        null|
# |GMF3253|MERCEDES BENZ|        VAN SPRINTER|           Bom|       2000|2000-01-29| 336409|     57970.0|
# |GMF3254|    CHEVROLET|   PICK-UP S10 2.2 S|           Bom|       2000|2000-01-15| 151157|     24699.0|
# +-------+-------------+--------------------+--------------+-----------+----------+-------+------------+
# only showing top 20 rows

# %%
# Filtrando os veículos com mais de 20 anos de fabricação e estado de conservação Anti-econômico.
df.filter((df['AnoFabricao'] <= 2000) &
          (df['Conservação'] == 'Anti-econômico')).select(['Placa',
                                                           'Marca',
                                                           'Modelo',
                                                           'Conservação',
                                                           'AnoFabricao',
                                                           'DataCompra',
                                                           'KmAtual',
                                                           'ValorCompra']).show()
# Out:
# +-------+-------------+------------------+--------------+-----------+----------+-------+-----------+
# |  Placa|        Marca|            Modelo|   Conservação|AnoFabricao|DataCompra|KmAtual|ValorCompra|
# +-------+-------------+------------------+--------------+-----------+----------+-------+-----------+
# |GMF1564|   VOLKSWAGEN|        PARATI CLI|Anti-econômico|       1996|2012-01-11| 233615|    18290.0|
# |GMF1641|   VOLKSWAGEN|        GOL 1.6 MI|Anti-econômico|       1997|2013-01-17|  57315|       null|
# |GMF1750|MERCEDES BENZ|      VAN SPRINTER|Anti-econômico|       1997|1997-01-04| 359394|       null|
# |GMF2445|MERCEDES BENZ|       ONIBUS 1314|Anti-econômico|       1987|1987-01-20|  32885|       null|
# |GMF2581|   VOLKSWAGEN|     KOMBI PICK-UP|Anti-econômico|       1986|1986-01-29|  79715|       null|
# |GMF2673|MERCEDES BENZ|  MICRO-ONIBUS 708|Anti-econômico|       1987|1987-01-06|  50841|       null|
# |GMF3257|    CHEVROLET| PICK-UP S10 2.2 S|Anti-econômico|       2000|2000-01-15| 118168|    24699.0|
# |GMF3260|    CHEVROLET|     GM/CORSA WIND|Anti-econômico|       2000|2000-01-15|  78656|    19563.0|
# |GMF3273|    CHEVROLET| PICK-UP S10 2.2 S|Anti-econômico|       2000|2000-01-15| 139103|    24699.0|
# |GMF3276|    CHEVROLET|     GM/CORSA WIND|Anti-econômico|       2000|2000-01-15| 297860|    19563.0|
# |GMF3299|   VOLKSWAGEN|MICRO ONIBUS 8-140|Anti-econômico|       2000|2001-01-16| 240367|       null|
# |GSM6051|MERCEDES BENZ|      VAN SPRINTER|Anti-econômico|       1997|1998-01-13| 266627|    36458.0|
# |GSO8541|   VOLKSWAGEN|  KOMBI - STANDARD|Anti-econômico|       1998|1998-01-13| 146999|    17830.0|
# +-------+-------------+------------------+--------------+-----------+----------+-------+-----------+

# %%
# Visualizando todos os veículos que não são movidos a Diesel.
df.filter(~(df['Combustível'] == 'Diesel')).select(['Placa',
                                                    'Marca',
                                                    'Modelo',
                                                    'ValorCompra']).show()
# Out:
# +-------+----------+--------------------+-----------+
# |  Placa|     Marca|              Modelo|ValorCompra|
# +-------+----------+--------------------+-----------+
# |GMF1564|VOLKSWAGEN|          PARATI CLI|    18290.0|
# |GMF1641|VOLKSWAGEN|          GOL 1.6 MI|       null|
# |GMF2581|VOLKSWAGEN|       KOMBI PICK-UP|       null|
# |GMF3059|      FIAT|      STRADA WORKING|       null|
# |GMF3242|      FORD|PICK-UP COURIER 1...|       null|
# |GMF3245| CHEVROLET|   PICK-UP S10 2.2 S|    24699.0|
# |GMF3249|VOLKSWAGEN|    KOMBI - STANDARD|       null|
# |GMF3252|VOLKSWAGEN|    KOMBI - STANDARD|       null|
# |GMF3254| CHEVROLET|   PICK-UP S10 2.2 S|    24699.0|
# |GMF3257| CHEVROLET|   PICK-UP S10 2.2 S|    24699.0|
# |GMF3260| CHEVROLET|       GM/CORSA WIND|    19563.0|
# |GMF3262| CHEVROLET|       GM/CORSA WIND|    19563.0|
# |GMF3273| CHEVROLET|   PICK-UP S10 2.2 S|    24699.0|
# |GMF3276| CHEVROLET|       GM/CORSA WIND|    19563.0|
# |GMF3314|VOLKSWAGEN|    KOMBI - STANDARD|       null|
# |GMF3523|   REBOQUE|             REBOQUE|      400.0|
# |GMF4073| CHEVROLET|               ASTRA|       null|
# |GMF4307|      FIAT|  PALIO WK ADVENTURE|       null|
# |GMF4316|   REBOQUE|             REBOQUE|     1150.0|
# |GMF4322|   REBOQUE|             REBOQUE|       null|
# +-------+----------+--------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# ## Identificando valores nulos

# %%
# Contanto as linhas com informações vazias.
# Por algum motivo o PySpark não consegue lidar com as colunas do tipo data nessa checagem, então vamos elinar estas colunas
# AnalysisException: cannot resolve 'isnan(DataCompra)' due to data type mismatch: argument 1 requires (double or float) type, however, 'DataCompra' is of date type.
df.select([sql_f.count(sql_f.when(sql_f.isnan(column) | sql_f.col(column).isNull(), column)).alias(column) for column in df.columns if column not in ['DataCompra', 'DataVenda']]).show(vertical=True)
# Out:
# -RECORD 0----------
#  Placa       | 3
#  Modelo      | 6
#  Marca       | 6
#  AnoFabricao | 7
#  Combustível | 12
#  Chassi      | 6
#  Cor         | 13
#  Potência    | 39
#  Cilindro    | 44
#  Aquisição   | 17
#  Conservação | 6
#  Situação    | 6
#  Combustivel | 12
#  Renavam     | 6
#  Tipo        | 6
#  Motor       | 109
#  Caixa       | 241
#  Local       | 273
#  KmAtual     | 6
#  NotaCompra  | 11
#  ValorCompra | 69
#  NumApolice  | 258

# %%
def show_null(data_frame, column):
  print(f'----{column.upper()}----------------')
  data_frame.filter(sql_f.col(column).isNull()).show()

# %%
# Visualizando as linhas vazias nas colunas.
[show_null(df, column) for column in df.columns]
# Out:
# ----PLACA----------------
# +-----+------+-----+-----------+-----------+------+----+--------+--------+---------+-----------+--------+-----------+-------+----+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
# |Placa|Modelo|Marca|AnoFabricao|Combustível|Chassi| Cor|Potência|Cilindro|Aquisição|Conservação|Situação|Combustivel|Renavam|Tipo|Motor|Caixa|Local|KmAtual|DataCompra|DataVenda|NotaCompra|ValorCompra|NumApolice|
# +-----+------+-----+-----------+-----------+------+----+--------+--------+---------+-----------+--------+-----------+-------+----+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
# | null|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# | null|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# | null|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# +-----+------+-----+-----------+-----------+------+----+--------+--------+---------+-----------+--------+-----------+-------+----+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
#
# ----MODELO----------------
# +--------------------+------+-----+-----------+-----------+------+----+--------+--------+---------+-----------+--------+-----------+-------+----+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
# |               Placa|Modelo|Marca|AnoFabricao|Combustível|Chassi| Cor|Potência|Cilindro|Aquisição|Conservação|Situação|Combustivel|Renavam|Tipo|Motor|Caixa|Local|KmAtual|DataCompra|DataVenda|NotaCompra|ValorCompra|NumApolice|
# +--------------------+------+-----+-----------+-----------+------+----+--------+--------+---------+-----------+--------+-----------+-------+----+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
# |                null|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# |                null|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# |                null|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# |           TOTAL 267|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# |RELATÓRIO DE VEÍC...|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# |Da depart. :   até :|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# +--------------------+------+-----+-----------+-----------+------+----+--------+--------+---------+-----------+--------+-----------+-------+----+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
#
# ----MARCA----------------
# +--------------------+------+-----+-----------+-----------+------+----+--------+--------+---------+-----------+--------+-----------+-------+----+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
# |               Placa|Modelo|Marca|AnoFabricao|Combustível|Chassi| Cor|Potência|Cilindro|Aquisição|Conservação|Situação|Combustivel|Renavam|Tipo|Motor|Caixa|Local|KmAtual|DataCompra|DataVenda|NotaCompra|ValorCompra|NumApolice|
# +--------------------+------+-----+-----------+-----------+------+----+--------+--------+---------+-----------+--------+-----------+-------+----+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
# |                null|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# |                null|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# |                null|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# |           TOTAL 267|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# |RELATÓRIO DE VEÍC...|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# |Da depart. :   até :|  null| null|       null|       null|  null|null|    null|    null|     null|       null|    null|       null|   null|null| null| null| null|   null|      null|     null|      null|       null|      null|
# +--------------------+------+-----+-----------+-----------+------+----+--------+--------+---------+-----------+--------+-----------+-------+----+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
#
# ----ANOFABRICAO----------------
# +--------------------+------------------+-----+-----------+-----------+-----------------+----+--------+--------+---------+-----------+--------+-----------+----------+---------------+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
# |               Placa|            Modelo|Marca|AnoFabricao|Combustível|           Chassi| Cor|Potência|Cilindro|Aquisição|Conservação|Situação|Combustivel|   Renavam|           Tipo|Motor|Caixa|Local|KmAtual|DataCompra|DataVenda|NotaCompra|ValorCompra|NumApolice|
# +--------------------+------------------+-----+-----------+-----------+-----------------+----+--------+--------+---------+-----------+--------+-----------+----------+---------------+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
# |             GMF8534|VAN DUCATO MINIBUS| FIAT|       null|   Gasolina|3C6EFVEK7KE521150|null|    null|    null|     null|      Ótimo|   Ativa|   Gasolina|1190028651|PAS/MICROONIBUS| null| null| null|  24147|2019-01-29|     null|   1022638|   152390.0|      null|
# |                null|              null| null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|           null| null| null| null|   null|      null|     null|      null|       null|      null|
# |                null|              null| null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|           null| null| null| null|   null|      null|     null|      null|       null|      null|
# |                null|              null| null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|           null| null| null| null|   null|      null|     null|      null|       null|      null|
# |           TOTAL 267|              null| null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|           null| null| null| null|   null|      null|     null|      null|       null|      null|
# |RELATÓRIO DE VEÍC...|              null| null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|           null| null| null| null|   null|      null|     null|      null|       null|      null|
# |Da depart. :   até :|              null| null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|           null| null| null| null|   null|      null|     null|      null|       null|      null|
# +--------------------+------------------+-----+-----------+-----------+-----------------+----+--------+--------+---------+-----------+--------+-----------+----------+---------------+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
#
# ----COMBUSTÍVEL----------------
# +--------------------+--------------------+----------+-----------+-----------+-----------------+------+--------+--------+--------------------+--------------+--------+-----------+----------+-------------+----------+-----+-----+-------+----------+---------+----------+-----------+----------+
# |               Placa|              Modelo|     Marca|AnoFabricao|Combustível|           Chassi|   Cor|Potência|Cilindro|           Aquisição|   Conservação|Situação|Combustivel|   Renavam|         Tipo|     Motor|Caixa|Local|KmAtual|DataCompra|DataVenda|NotaCompra|ValorCompra|NumApolice|
# +--------------------+--------------------+----------+-----------+-----------+-----------------+------+--------+--------+--------------------+--------------+--------+-----------+----------+-------------+----------+-----+-----+-------+----------+---------+----------+-----------+----------+
# |             GMF5170|      UNO MILLE FIRE|      FIAT|       2007|       null|9BD15822774948458|BRANCA|    66CV|       4|              COMPRA|Anti-econômico|   Ativa|       null| 915797810|PAS/AUTOMOVEL|         1| null| null| 115285|2007-01-20|     null|    675064|    23900.0|      null|
# |             GMF5173|      UNO MILLE FIRE|      FIAT|       2007|       null|9BD15822774948429|BRANCA|    66CV|       4|              COMPRA|         Ótimo|   Ativa|       null| 915800683|PAS/AUTOMOVEL|      null| null| null|  78720|2007-01-20|     null|    675062|    23900.0|      null|
# |             GMF8355|LOGAN EXP. 1.6 SCE|  RENAULT|       2018|   Gasolina|93Y4SRFH4JJ287849|null|  118 CV|       4|   COMPRA|      Ótimo|   Ativa|   Gasolina|1150543350|       PAS/AUTOMOVEL|H4ME734Q037126| null| null|  78965|2018-01-21|      null|      3208|    54240.0|      null|
# |             GMF8533|            CRONOS|     FIAT|       2018|   Gasolina|8AP359A2SKU039067|null|    null|    null|     null|      Ótimo|   Ativa|   Gasolina|1194879354|       PAS/AUTOMOVEL|          null| null| null|  22484|2019-01-06|      null|   1030298|    61891.0|      null|
# |             GMF8534|VAN DUCATO MINIBUS|     FIAT|       null|   Gasolina|3C6EFVEK7KE521150|null|    null|    null|     null|      Ótimo|   Ativa|   Gasolina|1190028651|     PAS/MICROONIBUS|          null| null| null|  24147|2019-01-29|      null|   1022638|   152390.0|      null|
# |             OPF6541| PICK-UP S10 2.2 S|CHEVROLET|       2012|   Gasolina|9BG148DH0DC442931|null|    null|    null|     null|      Ótimo|   Ativa|   Gasolina| 507825977|CAR/CAMION./C.ABERTA|          null| null| null|  55852|2019-01-15|      null|         0|       null|      null|
# |                null|              null|     null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|                null|          null| null| null|   null|      null|      null|      null|       null|      null|
# |                null|              null|     null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|                null|          null| null| null|   null|      null|      null|      null|       null|      null|
# |                null|              null|     null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|                null|          null| null| null|   null|      null|      null|      null|       null|      null|
# |           TOTAL 267|              null|     null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|                null|          null| null| null|   null|      null|      null|      null|       null|      null|
# |RELATÓRIO DE VEÍC...|              null|     null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|                null|          null| null| null|   null|      null|      null|      null|       null|      null|
# |Da depart. :   até :|              null|     null|       null|       null|             null|null|    null|    null|     null|       null|    null|       null|      null|                null|          null| null| null|   null|      null|      null|      null|       null|      null|
# +--------------------+------------------+---------+-----------+-----------+-----------------+----+--------+--------+---------+-----------+--------+-----------+----------+--------------------+--------------+-----+-----+-------+----------+----------+----------+-----------+----------+
#
# ----POTÊNCIA----------------
# +-------+------------------+----------+-----------+-----------+-----------------+--------+--------+--------+--------------------+--------------+--------+-----------+----------+--------------------+----------+-----+-----+-------+----------+----------+----------+-----------+----------+
# |  Placa|            Modelo|     Marca|AnoFabricao|Combustível|           Chassi|     Cor|Potência|Cilindro|           Aquisição|   Conservação|Situação|Combustivel|   Renavam|                Tipo|     Motor|Caixa|Local|KmAtual|DataCompra| DataVenda|NotaCompra|ValorCompra|NumApolice|
# +-------+------------------+----------+-----------+-----------+-----------------+--------+--------+--------+--------------------+--------------+--------+-----------+----------+--------------------+----------+-----+-----+-------+----------+----------+----------+-----------+----------+
# |GMF3523|           REBOQUE|   REBOQUE|       1986|     Outros|   MBLS0002271REM|   CINZA|    null|    null|              DOACAO|       Regular|   Ativa|     Outros| 244994633|CAR/REBOQUE/C.ABERTA|      null| null| null|      0|1986-01-20|      null|         0|      400.0|      null|
# |GMF4316|           REBOQUE|   REBOQUE|       2003|     Outros|9A9CG05113BDJ4063|   VERDE|    null|    null|DOACAO-CONTRATO-0...|           Bom|   Ativa|     Outros| 806694602|CAR/REBOQUE/C.ABERTA|      null| null| null|      0|2003-01-30|      null|         0|     1150.0|      null|
# |GMF4322|           REBOQUE|   REBOQUE|       1983|     Outros|   UFMG3611183REM|    null|    null|    null|              COMPRA|       Regular|   Ativa|     Outros| 239907477|CAR/REBOQUE/C.ABERTA|      null| null| null|      0|2003-01-08|2003-01-08|         0|       null|    OF4817|
# |GMF4334|     CORSA CLASSIC| G. MOTORS|       2003|   Gasolina|9BGSB19N04B106586|  BRANCA|    null|       4|              COMPRA|Anti-econômico|   Ativa|   Gasol
CV|       4|              COMPRA|           Bom|   Ativa|   Gasolina|749931426|CAR/CAMION./C.ABERTA|  1,6|  1,6| null|  66961|2000-01-12|     null|         0|        null|      null|
# |GMF3245|   PICK-UP S10 2.2 S|    CHEVROLET|       2000|   Gasolina|9BG124ASOYC440357|             BRANCA|    113 CV|       4|              COMPRA|           Bom|   Ativa|   Gasolina|749674199|CAR/CAMION./C.ABERTA|  2,2| null| null| 187303|2000-01-15|     null|         0|     24699.0|      null|
# |GMF3249|    KOMBI - STANDARD|   VOLKSWAGEN|       2000|   Gasolina|9BWGB07X51P008332|             BRANCA|     61 CV|       4|              COMPRA|           Bom|   Ativa|   Gasolina|749932023|MIS/CAMION./C.FEC...|  1,6|  1,6| null|  81075|2000-01-18|     null|         0|        null|      null|
# |GMF3253|        VAN SPRINTER|MERCEDES BENZ|       2000|     Diesel|8AC6903411A545194|             BRANCA|    115 CV|       4|              COMPRA|           Bom|   Ativa|     Diesel|749932805|     PAS/MICROONIBUS| null| null| null| 336409|2000-01-29|     null|         0|     57970.0|      null|
# |GMF3254|   PICK-UP S10 2.2 S|    CHEVROLET|       2000|   Gasolina|9BG124AS0YC440416|             BRANCA|    113 CV|       4|              COMPRA|           Bom|   Ativa|   Gasolina|749933283|CAR/CAMION./C.ABERTA|  2,2| null| null| 151157|2000-01-15|     null|         0|     24699.0|      null|
# |GMF3256|        CAMINHAO 710|MERCEDES BENZ|       2000|     Diesel|9BM688156YB252803|             BRANCA|       109|       4|              COMPRA|           Bom|   Ativa|     Diesel|749932546|CAR/CAMINHAO/C.AB...|  710| null| null| 109535|2000-01-28|     null|    274174|     41922.0|      null|
# +-------+--------------------+-------------+-----------+-----------+-----------------+-------------------+----------+--------+--------------------+--------------+--------+-----------+---------+--------------------+-----+-----+-----+-------+----------+---------+----------+------------+----------+
# only showing top 20 rows
#
# ----NOTACOMPRA----------------
# +--------------------+------------------+-------+-----------+-----------+-----------------+------+--------+--------+----------+-----------+--------+-----------+----------+---------------+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
# |               Placa|            Modelo|  Marca|AnoFabricao|Combustível|           Chassi|   Cor|Potência|Cilindro| Aquisição|Conservação|Situação|Combustivel|   Renavam|           Tipo|Motor|Caixa|Local|KmAtual|DataCompra|DataVenda|NotaCompra|ValorCompra|NumApolice|
# +--------------------+------------------+-------+-----------+-----------+-----------------+------+--------+--------+----------+-----------+--------+-----------+----------+---------------+-----+-----+-----+-------+----------+---------+----------+-----------+----------+
# |             GMF5293|VAN DUCATO MINIBUS|   FIAT|       2007|     Diesel|93W244M2382019405|BRANCA|    null|    null|DOAÇÃO TRT|      Ótimo|   Ativa|     Diesel| 937593699|PAS/MICROONIBUS| null| null| null| 103762|2021-01-11|     null|      null|    47850.0|      null|
# |             GMF7309|   JUMPER M33M 23S|CITROEN|       2013|   Gasolina|935ZBWMMBD2111026|  null|   127CV|    null|    DOAÇÃO|      Ótimo|   Ativa|   Gasolina| 529887339|  PAS/AUTOMOVEL| null| null| null|      0|2021-01-18|     null|      null|    76000.0|      null|
# |             GMF7723|           FLUENCE|RENAULT|       2014|   Gasolina|8A1LZBW2TEL265424| PRETA|   143CV|    null|DOAÇÃO TRT|      Ótimo|   Ativa|   Gasolina| 998886165|  PAS/AUTOMOVEL| null| null| null|  63855|2021-01-11|     null|      null|    47000.0|      null|
# |             GMF7725|           FLUENCE|RENAULT|       2014|   Gasolina|8A1LZBW2TEL265496| PRETA|   143CV|    null|DOAÇÃO TRT|      Ótimo|   Ativa|   Gasolina| 998870587|  PAS/AUTOMOVEL| null| null| null|  65588|2021-01-11|     null|      null|    47000.0|      null|
RANCA|     61 CV|       4|              COMPRA|           Bom|   Ativa|   Gasolina|749932023|MIS/CAMION./C.FEC...|  1,6|  1,6| null|  81075|2000-01-18|      null|         0|       null|      null|
# |GMF3252|    KOMBI - STANDARD|   VOLKSWAGEN|       2001|   Gasolina|9BWGB07X11P008263|             BRANCA|     61 CV|       4|              COMPRA|           Bom|   Ativa|   Gasolina|749932872|MIS/CAMION./C.FEC...|  1,6|  1,6| null| 193323|2000-01-14|2017-01-16|         0|       null|      null|
# |GMF3253|        VAN SPRINTER|MERCEDES BENZ|       2000|     Diesel|8AC6903411A545194|             BRANCA|    115 CV|       4|              COMPRA|           Bom|   Ativa|     Diesel|749932805|     PAS/MICROONIBUS| null| null| null| 336409|2000-01-29|      null|         0|    57970.0|      null|
# |GMF3254|   PICK-UP S10 2.2 S|    CHEVROLET|       2000|   Gasolina|9BG124AS0YC440416|             BRANCA|    113 CV|       4|              COMPRA|           Bom|   Ativa|   Gasolina|749933283|CAR/CAMION./C.ABERTA|  2,2| null| null| 151157|2000-01-15|      null|         0|    24699.0|      null|
# |GMF3256|        CAMINHAO 710|MERCEDES BENZ|       2000|     Diesel|9BM688156YB252803|             BRANCA|       109|       4|              COMPRA|           Bom|   Ativa|     Diesel|749932546|CAR/CAMINHAO/C.AB...|  710| null| null| 109535|2000-01-28|      null|    274174|    41922.0|      null|
# |GMF3257|   PICK-UP S10 2.2 S|    CHEVROLET|       2000|   Gasolina|9BG124ASOYC439993|             BRANCA|    113 CV|       4|              COMPRA|Anti-econômico|   Ativa|   Gasolina|749933704|CAR/CAMION./C.ABERTA|  2,2| null| null| 118168|2000-01-15|      null|         0|    24699.0|      null|
# |GMF3259|PICK-UP GM/S10 2.8 S|    CHEVROLET|       2001|     Diesel|9BG124AC01C404825|             BRANCA|    132 CV|       4|              COMPRA|           Bom|   Ativa|     Diesel|749934255|CAR/CAMION./C.ABERTA|  2,8| null| null| 285945|2000-01-15|      null|         0|    35795.0|      null|
# |GMF3260|       GM/CORSA WIND|    CHEVROLET|       2000|   Gasolina|9BGSC68N01C166156|             BRANCA|     92 CV|       4|              COMPRA|Anti-econômico|   Ativa|   Gasolina|749943904|       PAS/AUTOMOVEL|  1,6|  1,6| null|  78656|2000-01-15|      null|         0|    19563.0|      null|
# |GMF3262|       GM/CORSA WIND|    CHEVROLET|       2000|   Gasolina|9BGSC68N01C166607|             BRANCA|     92 CV|       4|              COMPRA|           Bom|   Ativa|   Gasolina|749965177|       PAS/AUTOMOVEL|  1,6|  1,6| null| 140234|2000-01-15|      null|         0|    19563.0|      null|
# |GMF3273|   PICK-UP S10 2.2 S|    CHEVROLET|       2000|   Gasolina|9BG124ASOYC440510|             BRANCA|    113 CV|       4|              COMPRA|Anti-econômico|   Ativa|   Gasolina|749975911|CAR/CAMION./C.ABERTA|  2,2| null| null| 139103|2000-01-15|      null|         0|    24699.0|      null|
# |GMF3276|       GM/CORSA WIND|    CHEVROLET|       2000|   Gasolina|9BGSC68N01C166619|             BRANCA|     92 CV|       4|              COMPRA|Anti-econômico|   Ativa|   Gasolina|749977515|       PAS/AUTOMOVEL|  1,6|  1,6| null| 297860|2000-01-15|2017-01-16|         0|    19563.0|      null|
# +-------+--------------------+-------------+-----------+-----------+-----------------+-------------------+----------+--------+--------------------+--------------+--------+-----------+---------+--------------------+-----+-----+-----+-------+----------+----------+----------+-----------+----------+
# only showing top 20 rows
#
# Out[96]: [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# ## Lidando com valores nulos
